# %% [markdown]
# # Advance Data Visualization

# %% [markdown]
# $\textbf{Bachelor's Degree Women USA}$
#
# The Department of Education Statistics releases a data set annually containing the percentage of bachelor's degrees granted to women. The data set is broken up into 17 categories of degrees, with each column as a separate category. Randal Olson has made it available on his personal website.
#
# - Personal [website](http://www.randalolson.com/wp-content/uploads/)
# - Kaggle [website](https://www.kaggle.com/sureshsrinivas/bachelorsdegreewomenusa)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
df.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Agriculture', 'Architecture', 'Art and Performance', 'Biology',
#        'Business', 'Communications and Journalism', 'Computer Science',
#        'Education', 'Engineering', 'English', 'Foreign Languages',
#        'Health Professions', 'Math and Statistics', 'Physical Sciences',
#        'Psychology', 'Public Administration', 'Social Sciences and History'],
#       dtype='object')

# %%
df = pd.read_csv('percent-bachelors-degrees-women-usa.csv')

# set columns we will be used
year = df['Year']
physical_sciences = df['Physical Sciences']
computer_sciences = df['Computer Science']
psychology = df['Psychology']
business = df['Business']

df.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
plt.plot(df['Year'], df['Business'])

# %%
plt.plot(year, business)

# %%
plt.plot(year, physical_sciences) # == plt.plot('Year', 'Physical Sciences', data=df)

# %% [markdown]
# ## Using subplots

# %%
# single plot in one axes
plt.figure(figsize=(8,5))
plt.plot(year, physical_sciences);

# %%
# single plot in one axes
plt.subplots(1, 1, figsize=(8,5))
plt.plot(df['Year'], physical_sciences);

# %% [markdown]
# $\textbf{Now how if we want to make a single plot in a lot of axes?}$
#
# This is where $\textbf{subplots}$ does its job. The documentation can be seen [here](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplots.html)
#
# Create a figure and a set of subplots. This utility wrapper makes it convenient to create common layouts of subplots, including the enclosing figure object, in a single call.

# %% [markdown]
# ### One Axes

# %%
# single plot in one axes
fig, ax = plt.subplots(1,1, figsize=(8,5))
ax.plot(year, psychology);

# %%
# using seaborn
fig, axes = plt.subplots(1,1, figsize=(8,5))
sns.lineplot(x=year, y=physical_sciences, ax=axes);

# %%
# single plot in one axes
fig, axes = plt.subplots(1,1, figsize=(8,5))

# axes.plot('Year', 'Psychology', data=df); #matplolib version
sns.lineplot(x=year, y=business, ax=axes); #seaborn version

# %%
# single plot in one axes
fig, ax = plt.subplots(1,1, figsize=(8,5))

ax.plot(year, physical_sciences, color ='blue')
ax.plot(year, computer_sciences, color ='red')
ax.plot(year, business, color ='darkorange');

# %% [markdown]
# ### Multiple Axes

# %% [markdown]
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation. warnings.warn(. hiraukan aja ya?

# %%
fig, axes = plt.subplots(2, # number of rows
                     1, # number of columns
                     figsize=(8, 5))

# %%
fig, axes = plt.subplots(2, # number of rows
                     1, # number of columns
                     figsize=(8, 5), sharex=True, sharey=True)

axes[0].plot(year, business)
sns.lineplot(x=year, y=physical_sciences, ax=axes[1], color='r')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Physical Sciences'>

# %%
fig, axes = plt.subplots(3, # number of rows
                     2, # number of columns
                     figsize=(8, 5))

# %%
fig, ax = plt.subplots(4, # number of rows
                     1, # number of columns
                     figsize=(8, 5))

ax[1].plot(year, physical_sciences, color ='blue')
ax[1].plot(year, computer_sciences, color ='red');

# %%
fig, ax = plt.subplots(2, # number of rows
                     1, # number of columns
                     figsize=(8, 5),
                      sharey=True, sharex=True)

ax[0].plot(year, physical_sciences, color ='blue')
ax[0].plot(year, computer_sciences, color ='orange')

ax[1].plot(year, computer_sciences, color ='orange')
ax[1].plot(year, psychology, color ='red');

# %%
fig, axes = plt.subplots(3, # number of rows
                     3, # number of columns
                     figsize=(8, 5))

# axes[index row, index column]
axes[0,2].plot(year, physical_sciences, color ='blue');

# %% [markdown]
# ## Mengubah Warna

# %% [markdown]
# opsi untuk warna bisa dilihat di https://jonasjacek.github.io/colors/

# %%
plt.plot(year, physical_sciences, color ='green'); # color

# %% [markdown]
# Untuk mencari lebih banyak kombinasi palette: https://coolors.co/

# %%
plt.bar(year, physical_sciences, color ='#4DCCBD', alpha=0.3)
plt.plot(year, business, color ='#231651'); # color

# %%
plt.bar(year[:5], physical_sciences[:5], color='grey', alpha=0.5)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(year[:5], physical_sciences[:5], color=['grey', 'blue', 'grey', 'grey', 'blue']);

# %% [markdown]
# penggunaan palette: [source](https://chrisalbon.com/python/data_visualization/seaborn_color_palettes/)

# %%
fig, ax = plt.subplots(1,1, figsize=(8,5))
sns.barplot(x=year[:5], y=physical_sciences[:5], palette ='YlOrRd', ax=ax);

# %% [markdown]
# linestyle: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}

# %%
plt.figure(figsize = (8, 5))
plt.plot(year, physical_sciences, color ='blue', 
         linestyle='--', linewidth=2); #mengubah tipe line

# %%
plt.figure(figsize = (8, 5))
plt.plot(year, physical_sciences, color ='blue', 
         marker='o',
         markeredgecolor='red'
  );

# %% [markdown]
# ## Add Title

# %%
# plt.figure(figsize = (8, 5))
plt.plot(year, physical_sciences, color ='blue');

# %%
plt.figure(figsize = (8, 5))
# plt.plot(year, physical_sciences, color ='blue')
sns.lineplot(x=year, y=physical_sciences, color ='blue')

plt.title('Physical Sciences Bachelors over year', fontsize = 16);

# %%
fig, axes = plt.subplots(2, 1, figsize = (8, 5))
axes[0].plot(year, physical_sciences, color ='blue')
sns.lineplot(x=year, y=computer_sciences, color ='red', ax=axes[1])

axes[0].set_title('Physical Sciences Bachelors over year', fontsize = 16)
axes[1].set_title('Computer Sciences Bachelors over year', fontsize = 16);

# %% [markdown]
# Tapi judulnya bertumpuk dengan axis di axes ke-0, bagaimana cara menambah space antar axes?

# %%
fig, axes = plt.subplots(2, 1, figsize = (8, 5))
axes[0].plot(year, physical_sciences, color ='blue')
sns.lineplot(x=year, y=computer_sciences, color ='red', ax=axes[1])

axes[0].set_title('Physical Sciences Bachelors over year', fontsize = 16)
axes[1].set_title('Computer Sciences Bachelors over year', fontsize = 16)
fig.tight_layout(pad=1.0); # add spaces between subplots

# %% [markdown]
# ## Add label

# %%
plt.figure(figsize = (8, 5))
sns.lineplot(x=year, y=physical_sciences, color ='blue')
plt.title('Physical Sciences Bachelors over year', fontsize = 16)

# add label
plt.xlabel('Year', fontsize = 12)
plt.ylabel('Percentage Bachelors', fontsize = 12);

# %%
fig, ax = plt.subplots(2, 1, figsize = (8, 5), sharey=True)

ax[0].plot(year, physical_sciences, color ='blue')
ax[1].plot(year, computer_sciences, color ='red');

# %%
fig, axes = plt.subplots(2, 1, figsize = (8, 5),
                      sharex=True,
                      sharey=True
                      )

axes[0].plot(year, physical_sciences, color ='blue')
axes[1].plot(year, computer_sciences, color ='red')

# add label
axes[1].set_xlabel('Year', fontsize = 12)
axes[1].set_ylabel('Percentage Bachelors', fontsize = 12)
# axes[0].set_ylabel('Percentage Bachelors', fontsize = 12);
# Out:
# Text(0, 0.5, 'Percentage Bachelors')

# %%
fig, ax = plt.subplots(2, 1, figsize = (8, 5),
                      sharex=True)
ax[0].plot(year, physical_sciences, color ='blue')
ax[1].plot(year, computer_sciences, color ='red')

# add label
ax[1].set_xlabel('Year', fontsize = 12)
fig.text(0.05, 0.35, 'Percentage Bachelors', rotation='vertical', fontsize=12)
# Out:
# Text(0.05, 0.35, 'Percentage Bachelors')

# %% [markdown]
# ## X-Y limits

# %% [markdown]
# $\textbf{Using xlim(), ylim()}$
#
# In this exercise, you will work with the matplotlib.pyplot interface to quickly set the x- and y-limits of your plots.
#
# You will now create the same figure as in the previous exercise using plt.plot(), this time setting the axis extents using plt.xlim() and plt.ylim(). These commands allow you to either zoom or expand the plot or to set the axis ranges to include important values (such as the origin).
#
# In this exercise, as before, the percentage of women graduates in Computer Science and in the Physical Sciences are held in the variables computer_science and physical_sciences respectively over year.

# %%
plt.figure(figsize = (8, 5))
plt.plot(year, physical_sciences, color ='blue')
plt.plot(year, business, color ='red')

plt.title('Physical Sciences Bachelors over year', 
          fontsize = 16);

# %%
plt.figure(figsize = (8, 5))
plt.plot(year, physical_sciences, color ='blue')
plt.plot(year, business, color ='red')

plt.title('Physical Sciences Bachelors over year', 
          fontsize = 16)

# set the limit
plt.xlim(1990,2010)
plt.ylim(0, 100);

# %% [markdown]
# Pembagian x axis masih belum teratur, ada tahun 1992.5, 2002.5

# %%
list(range(1990, 2014, 4))
# Out:
# [1990, 1994, 1998, 2002, 2006, 2010]

# %%
plt.figure(figsize = (8, 5))
plt.plot(year, physical_sciences, color ='blue')
plt.title('Physical Sciences Bachelors over year', fontsize = 16)

# set the limit
plt.xlim(1990,2010)
plt.ylim(0, 50)
plt.xticks(range(1990, 2014, 4));

# %%
fig, ax = plt.subplots(2, 1, figsize = (8, 5),
                      sharex=True,
                      sharey=True)
ax[0].plot(year, physical_sciences, color ='blue')
ax[1].plot(year, computer_sciences, color ='red')

# set xlim ylim
ax[0].set_xlim(1990, 2010)
ax[0].set_ylim(0, 50)

# set ticks
ax[0].set_xticks(range(1990, 2014, 4));

# %% [markdown]
# ## set legend

# %% [markdown]
# $\textbf{Using legend()}$ documentation [here](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.legend.html)
#
# Legends are useful for distinguishing between multiple datasets displayed on common axes. The relevant data are created using specific line colors or markers in various plot commands. Using the keyword argument label in the plotting function associates a string to use in a legend.
#
# For example, here, you will plot enrollment of women in the Physical Sciences and in Computer Science over time. You can label each curve by passing a label argument to the plotting call, and request a legend using plt.legend(). Specifying the keyword argument loc determines where the legend will be placed.

# %%
plt.figure(figsize = (8, 5))
plt.plot(year, physical_sciences, color ='blue', label='physical')
plt.plot(year, computer_sciences, color ='red', label='computer')

plt.legend()

# %%
sns.lineplot(x=year, y=physical_sciences, color ='blue', label='physical')
sns.lineplot(x=year, y=computer_sciences, color ='red', label='computer')

plt.legend()

# %%
fig, axs = plt.subplots(2, # number of rows
                     1, # number of columns
                     figsize=(8, 5))

axs[0].plot(year, physical_sciences, label='physical', color ='blue')
axs[0].plot(year, business, label='computer', color = 'red')
axs[0].legend(loc = 'lower right')

sns.lineplot(x=year, y=computer_sciences, ax=axs[1], label='computer', color='darkorange')
axs[1].legend(loc = 'lower left');

# %% [markdown]
# ## Add text

# %%
plt.figure(figsize = (8, 5))
plt.plot(year, physical_sciences, color ='blue')

plt.text(x=1980, y=30, s='Warna Biru', color='green', fontsize=26, ha='center')
# Out:
# Text(1980, 30, 'Warna Biru')

# %%
plt.figure(figsize = (8, 5))
plt.plot(year, physical_sciences, color ='blue')
plt.plot(year, computer_sciences, color ='red')

plt.text(x=1979, y=33, s='computer sciences', rotation=62, color = 'red', fontsize=12, va='center', ha='center')
# Out:
# Text(1979, 33, 'computer sciences')

# %%
plt.figure(figsize = (8, 5))
plt.plot(year, physical_sciences, color ='blue')
plt.plot(year, computer_sciences, color ='red')

# add text
plt.text(1979,33,s='computer science',
        fontsize=12,
        color='red',
        rotation=63,
        ha='center',
        va='center'
    )

plt.text(1996,39,s='physical science',
        fontsize=12,
        color='blue',
        rotation=42,
        ha='center',
        va='center'
    )

plt.text(2010,8,s='Year',
        fontsize=14)

plt.text(1964,35,s='Percentage',
        fontsize=14, rotation=90)
# Out:
# Text(1964, 35, 'Percentage')

# %%
fig, axs = plt.subplots(2, # number of rows
                     1, # number of columns
                     sharex=True, sharey=True,
                     figsize=(8, 5))

axs[0].plot(year, physical_sciences, color ='blue')
axs[1].plot(year, computer_sciences, color = 'red')

# add text
axs[1].text(1974,23,s='computer science',
        fontsize=12,
        color='red',
        rotation=43)
# Out:
# Text(1974, 23, 'computer science')

# %% [markdown]
# ### Add data points

# %%
x = df['Year'][:6].astype(str)
y = df['Computer Science'][:6]

print(x)
print()
print(y)
# Out:
# 0    1970
# 1    1971
# 2    1972
# 3    1973
# 4    1974
# 5    1975
# Name: Year, dtype: object
#
# 0    13.6
# 1    13.6
# 2    14.9
# 3    16.4
# 4    18.9
# 5    19.8
# Name: Computer Science, dtype: float64

# %%
plt.figure(figsize=(8,5))
plt.bar(x=x, height=y)

plt.text(x = 1, y = 14.6, s = "13.6", ha='center')
# Out:
# Text(1, 14.6, '13.6')

# %%
plt.figure(figsize=(8,5))
plt.bar(x=x, height=y)

x_numbers = range(len(x))
for i in x_numbers:
    plt.text(x = x_numbers[i], y = y[i]+0.5, s = str(y[i]), size = 12, ha='center') # add data points
    
plt.ylim(0, 25)
# Out:
# (0.0, 25.0)

# %% [markdown]
# ## annotate

# %% [markdown]
# $\textbf{Using annotate()}$ documentation [here](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.annotate.html)
#
# It is often useful to annotate a simple plot to provide context. This makes the plot more readable and can highlight specific aspects of the data. Annotations like text and arrows can be used to emphasize specific observations.
#
# Here, you will once again plot enrollment of women in the Physical Sciences and Computer science over time. The legend is set up as before. Additionally, you will mark the inflection point when enrollment of women in Computer Science reached a peak and started declining using plt.annotate().
#
# To enable an arrow, set arrowprops=dict(facecolor='black'). The arrow will point to the location given by xy and the text will appear at the location given by xytext.

# %%
# Plot with legend as before
plt.plot(year, computer_sciences, color='red', label='Computer Science') 
plt.plot(year, physical_sciences, color='blue', label='Physical Sciences')

# %%
plt.figure(figsize=(8,5))
plt.plot(year, computer_sciences, color='red')
plt.ylim(10, 50)

plt.annotate(xy=(1983,37), xytext=(1983+5,37+5), text='maximum',
             fontsize=16,
            arrowprops=dict(
                            arrowstyle="->",
                            connectionstyle="arc3,rad=.3")
            );

# %% [markdown]
# ### Automate find maximum value

# %%
# Compute the maximum enrollment of women in Computer Science: cs_max
cs_max = computer_sciences.max()

# Calculate the year in which there was maximum enrollment of women in Computer Science: yr_max
yr_max = year[computer_sciences.idxmax()]

print(cs_max, yr_max)
# Out:
# 37.1 1983

# %%
# Plot with legend as before
plt.plot(year, computer_sciences, color='red', label='Computer Science') 
plt.plot(year, physical_sciences, color='blue', label='Physical Sciences')
# plt.legend(loc='lower right')

# Compute the maximum enrollment of women in Computer Science: cs_max
cs_max = computer_sciences.max()

# Calculate the year in which there was maximum enrollment of women in Computer Science: yr_max
yr_max = year[computer_sciences.idxmax()]

# Add a black arrow annotation
plt.annotate('Maximum', xy=(yr_max, cs_max), xytext=(yr_max+5, cs_max+5), 
             arrowprops=dict(
                             arrowstyle="->",
                            connectionstyle="arc3,rad=.3")
             );

# %% [markdown]
# Let's looping this, let say we want to annotate maximum value on every categories of degrees! How can we do it?
#
# The categories we want to annotate are physcial sciences, computer sciences, & business

# %%
fig, ax = plt.subplots(1, 1, figsize = (8,5))
x = year
ys = [physical_sciences, computer_sciences, business]

for y in ys:
    ax.plot(x, y, label=y.name)
    
    cs_max = y.max()
    yr_max = x[y.idxmax()]
    ax.annotate('Maximum', xy=(yr_max, cs_max), xytext=(yr_max+5, cs_max+5), 
                arrowprops=dict(arrowstyle="->",connectionstyle="arc3,rad=.3")
               )
    ax.legend(loc='lower right')
    
ax.set_xlabel('Year')
ax.set_ylabel('Enrollment (%)')
ax.set_title('Undergraduate enrollment of women')
ax.set_ylim(5, 60) # some minor adjustment
plt.savefig('fig/undergraduate_enrollment_of_women.png');

# %% [markdown]
# # Intro to Data Storytelling

# %% [markdown]
# ## Set style Matplotlib

# %%
# reset
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
import matplotlib.style as style
style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
style.use('seaborn-dark')
plt.plot(year, physical_sciences);

# %% [markdown]
# ## Set Style Seaborn

# %%
import seaborn as sns

# %%
sns.set_style('whitegrid')
sns.lineplot(x=year, y=physical_sciences)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Physical Sciences'>

# %%
sns.set_style('darkgrid')
sns.lineplot(x=year, y=physical_sciences)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Physical Sciences'>

# %%
sns.set_style('ticks')
sns.lineplot(x=year, y=physical_sciences)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Physical Sciences'>

# %% [markdown]
# ## Example

# %% [markdown]
# We want to create illustration like [FiveThirtyEight](https://fivethirtyeight.com/)

# %% [markdown]
# We now need to create a graph to help readers visualize the evolution of gender disparity for Bachelors where the situation was really bad for women in 1970. We’ve already set a threshold of 20%, and now we want to graph the evolution for every Bachelor where the percentage of women graduates was less than 20% in 1970. Source for this example is [DataQuest](https://www.dataquest.io/blog/making-538-plots/).

# %%
import matplotlib.style as style
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# %% [markdown]
# ### Take under 20% in 1970

# %%
df = pd.read_csv('csv/percent-bachelors-degrees-women-usa.csv')
women_majors = df.copy()

# %%
under_20 = women_majors.loc[0, df.loc[0] < 20]
under_20
# Out:
# Agriculture           4.229798
# Architecture         11.921005
# Business              9.064439
# Computer Science     13.600000
# Engineering           0.800000
# Physical Sciences    13.800000
# Name: 0, dtype: float64

# %%
under_20.index
# Out:
# Index(['Agriculture', 'Architecture', 'Business', 'Computer Science',
#        'Engineering', 'Physical Sciences'],
#       dtype='object')

# %% [markdown]
# ### Our first basic plot

# %%
under_20_graph = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8))
print('Type:', type(under_20_graph))
# Out:
# Type: <class 'matplotlib.axes._subplots.AxesSubplot'>

# %% [markdown]
# ### Change Style and Modify Axis Label

# %%
# The previous code
style.use('fivethirtyeight') # use style fivethirtyeight
fte_graph = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8))
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18) # increase label size

ticks_loc = fte_graph.get_yticks().tolist()
fte_graph.yaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
fte_graph.set_yticklabels(labels = [-10, '0   ', '10   ', '20   ', '30   ', '40   ', '50%', 60]); # modify y label

# %% [markdown]
# ### Add Line in Axis and Signature Bar

# %%
# The previous code
fte_graph = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8))
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)
fticks_loc = fte_graph.get_yticks().tolist()
fte_graph.yaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
fte_graph.set_yticklabels(labels = [-10, '0   ', '10   ', '20   ', '30   ', '40   ', '50%', 60]);

# Generate a bolded horizontal line at y = 0
fte_graph.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = .7)

# Add an extra vertical line by tweaking the range of the x-axis
fte_graph.set_xlim(left = 1969, right = 2011)

# Remove the label of the x-axis
fte_graph.xaxis.label.set_visible(False)

# The signature bar
fte_graph.text(x = 1965.8, y = -7,
    s = ' ©DATAQUEST Source: National Center for Education Statistics',fontsize = 14, 
               color = '#f0f0f0', backgroundcolor = 'grey')
# Out:
# Text(1965.8, -7, ' ©DATAQUEST Source: National Center for Education Statistics')

# %% [markdown]
# ### Add Title and Subtitle

# %%
# The previous code
fte_graph = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8))
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)
ticks_loc = fte_graph.get_yticks().tolist()
fte_graph.yaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
fte_graph.set_yticklabels(labels = [-10, '0   ', '10   ', '20   ', '30   ', '40   ', '50%', 60]);
fte_graph.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = .7)
fte_graph.set_xlim(left = 1969, right = 2011)
fte_graph.xaxis.label.set_visible(False)
fte_graph.text(x = 1965.8, y = -7,
    s = ' ©DATAQUEST Source: National Center for Education Statistics',fontsize = 14, 
               color = '#f0f0f0', backgroundcolor = 'grey')


# Adding a title and a subtitle
fte_graph.text(x = 1966.65, y = 62.7, s = "The gender gap is transitory - even for extreme cases",
               fontsize = 26, weight = 'bold', alpha = .75)
fte_graph.text(x = 1966.65, y = 57,
               s = 'Percentage of Bachelors conferred to women from 1970 to 2011 in the US for\nextreme cases where the percentage was less than 20% in 1970',
              fontsize = 19, alpha = .85)
# Out:
# Text(1966.65, 57, 'Percentage of Bachelors conferred to women from 1970 to 2011 in the US for\nextreme cases where the percentage was less than 20% in 1970')

# %% [markdown]
# ### Change colors to Colorblind-friendly colors

# %%
# Colorblind-friendly colors
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255],
          [213/255,94/255,0], [0,114/255,178/255]]

# The previous code we modify
fte_graph = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8), color = colors)

# The previous code remain the same
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)
ticks_loc = fte_graph.get_yticks().tolist()
fte_graph.yaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
fte_graph.set_yticklabels(labels = [-10, '0   ', '10   ', '20   ', '30   ', '40   ', '50%', 60]);
fte_graph.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = .7)
fte_graph.set_xlim(left = 1969, right = 2011)
fte_graph.xaxis.label.set_visible(False)
fte_graph.text(x = 1965.8, y = -7,
    s = ' ©DATAQUEST Source: National Center for Education Statistics',fontsize = 14, 
               color = '#f0f0f0', backgroundcolor = 'grey')
fte_graph.text(x = 1966.65, y = 62.7, s = "The gender gap is transitory - even for extreme cases",
               fontsize = 26, weight = 'bold', alpha = .75)
fte_graph.text(x = 1966.65, y = 57,
               s = 'Percentage of Bachelors conferred to women from 1970 to 2011 in the US for\nextreme cases where the percentage was less than 20% in 1970',
              fontsize = 19, alpha = .85)
# Out:
# Text(1966.65, 57, 'Percentage of Bachelors conferred to women from 1970 to 2011 in the US for\nextreme cases where the percentage was less than 20% in 1970')

# %% [markdown]
# ### Add colored labels

# %%
# The previous code we modify
fte_graph = women_majors.plot(x = 'Year', y = under_20.index, figsize = (12,8), color = colors, legend = False)

# The previous code remain the same
fte_graph.tick_params(axis = 'both', which = 'major', labelsize = 18)
ticks_loc = fte_graph.get_yticks().tolist()
fte_graph.yaxis.set_major_locator(mticker.FixedLocator(ticks_loc))
fte_graph.set_yticklabels(labels = [-10, '0   ', '10   ', '20   ', '30   ', '40   ', '50%', 60]);
fte_graph.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = .7)
fte_graph.set_xlim(left = 1969, right = 2011)
fte_graph.xaxis.label.set_visible(False)
fte_graph.text(x = 1965.8, y = -7,
    s = ' ©DATAQUEST Source: National Center for Education Statistics',fontsize = 14, 
               color = '#f0f0f0', backgroundcolor = 'grey')
fte_graph.text(x = 1966.65, y = 62.7, s = "The gender gap is transitory - even for extreme cases",
               fontsize = 26, weight = 'bold', alpha = .75)
fte_graph.text(x = 1966.65, y = 57,
               s = 'Percentage of Bachelors conferred to women from 1970 to 2011 in the US for\nextreme cases where the percentage was less than 20% in 1970',
              fontsize = 19, alpha = .85)

# Add colored labels
fte_graph.text(x = 1994, y = 44, s = 'Agriculture', color = colors[0], weight = 'bold', rotation = 33,
              backgroundcolor = '#f0f0f0')
fte_graph.text(x = 1985, y = 42.2, s = 'Architecture', color = colors[1], weight = 'bold', rotation = 18,
              backgroundcolor = '#f0f0f0')
fte_graph.text(x = 2004, y = 51, s = 'Business', color = colors[2], weight = 'bold', rotation = -5,
               backgroundcolor = '#f0f0f0')
fte_graph.text(x = 2001, y = 30, s = 'Computer Science', color = colors[3], weight = 'bold', rotation = -42.5,
              backgroundcolor = '#f0f0f0')
fte_graph.text(x = 1987, y = 11.5, s = 'Engineering', color = colors[4], weight = 'bold',
              backgroundcolor = '#f0f0f0')
fte_graph.text(x = 1976, y = 25, s = 'Physical Sciences', color = colors[5], weight = 'bold', rotation = 27,
              backgroundcolor = '#f0f0f0');
